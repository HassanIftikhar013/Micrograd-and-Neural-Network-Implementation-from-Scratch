# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
    return x**23+2*x**2-2*x+3
def derivative(x):
    h=0.0000001
    f_x_add_h =func

# %%
x = np.linspace(-5,5,5)
y=f(x)

# %%
h=0.000001
plt.plot(x,(f(x+h)-f(x))/h)

# %%
plt.plot(x,f(x))
